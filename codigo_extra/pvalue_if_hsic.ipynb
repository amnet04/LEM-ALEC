# %% [markdown]
# # HSIC multitreading

# %% [markdown]
# ## Carga de librerías

# %%
import csv
import numpy
import pandas
import time
from hsic import HSIC

# %%
## Definición de constantes

# %%
data=(
#longitude,latitude,radius,city,department
(7.866667,-76.666667,15,"Apartadó","Antioquia"),
(7.084512,-70.755366,15,"Arauca","Arauca"),
(4.533889,-75.681111,15,"Armenia","Quindio"),
(7.065278,-73.854722,15,"Barrancabermeja","Santander"),
(10.9838942,-74.853037,15,"Barranquilla","Atlántico"),
(4.649178,-74.062827,15,"Bogotá","Bogotá D.C."),
(7.125393,-73.119804,15,"Bucaramanga","Santander"),
(3.880099,-77.031164,15,"Buenaventura","Valle del Cauca"),
(3.437222,-76.5225,15,"Cali","Valle del Cauca"),
(10.399722,-75.514444,15,"Cartagena","Bolívar"),
(7.893907,-72.507821,15,"Cúcuta","Norte de Santander"),
(1.614382,-75.606229,15,"Florencia","Caquetá"),
(4.438889,-75.232222,15,"Ibagué","Tolima"),
(9.242024,-74.754671,15,"Magangué","Bolívar"),
(5.06889,-75.517383,15,"Manizales","Caldas"),
(6.25184,-75.563591,15,"Medellín","Antioquia"),
(8.747984,-75.881428,15,"Montería","Cordoba"),
(2.927299,-75.281885,15,"Neiva","Huila"),
(1.213611,-77.281111,15,"Pasto","Nariño"),
(4.813333,-75.696111,15,"Pereira","Risaralda"),
(2.4574702,-76.6349535,15,"Popayán","Cauca"),
(5.694722,-76.661111,15,"Quibdó","Chocó"),
(11.544444,-72.907222,15,"Ríohacha","La Guajira"),
(12.584722,-81.700556,15,"San Andrés","San Andrés y Prov."),
(11.240791,-74.19904,15,"Santa Marta","Magdalena"),
(9.304722,-75.397778,15,"Sincelejo","Sucre"),
(4.084656,-76.19536,15,"Tuluá","Valle del Cauca"),
(5.535278,-73.367778,15,"Tunja","Boyacá"),
(10.46314,-73.253224,15,"Valledupar","Cesar"),
(4.142002,-73.626645,15,"Villavicencio","Meta"),
(5.337752,-72.395859,15,"Yopal","Casanare"),
(4.3113937,-74.8281867,7,"Girardot","Cundinamarca"),
(-4.203122,-69.9600086,7,"Leticia","Amazonas"),
(5.0215184,-74.006701,7,"Zipaquirá","Cundinamarca"),
(1.7875194,-78.7998601,7,"Tumaco","Nariño"),
(11.716254,-72.26898,7,"Uribia","La Guajira"),
(8.0855821,-76.748706,7,"Turbo","Antioquia"),
(11.3802126,-72.277558,7,"Maicao","Guajira"),
(0.8262647,-77.672631,7,"Ipiales","Nariño"),
(4.3387893,-74.419436,7,"Fusagasugá","Cundinamarca"),
(1.8530659,-76.0900245,7,"Pitalito","Huila"),
(3.2613152,-76.559418,7,"Jamundí","Valle del Cauca"),
(6.1448793,-75.392638,7,"Rionegro","Antioquia"),
(9.2425334,-75.8367556,7,"Lorica","Cordoba"),
(7.9786912,-75.2153806,7,"Caucasia","Antioquia"),
(3.8991844,-76.3346675,7,"Buga","Valle del Cauca"),
(5.8260758,-73.0652311,5,"Duitama","Boyaca"),
(7.5832126,-75.4087427,7,"Tarazá","Antioquia"),
(6.9640417,-75.4281362,7,"Yarumal","Antioquia"),
(7.9640411,-74.0602612,7,"Santa Rosa del Sur","Bolivar"),
(6.908181,-75.0866407,7,"Amalfi","Antioquia"),
(6.5999922,-75.0323326,7,"Yolombó","Antioquia"),
(6.0424652,-74.9994596,7,"San Luis","Antioquia"),
(13.3532482,-81.4077916,7,"Providencia","San Andres"),
(10.4940449,-75.1288534,7,"Repelón","Atlantico"),
(10.2326969,-75.1954292,7,"Mahates","Bolivar"),
(8.920686,-74.4754601,7,"Pinillos","Bolivar"),
(8.5559311,-74.2700317,7,"Tiquisio","Bolivar"),
(5.413252,-74.9937061,7,"Samaná","Caldas"),
(5.3832461,-75.1663995,7,"Pensilvania","Caldas"),
(5.8998651,-74.7389946,7,"Doradal","Antioquia"),
(1.3344568,-74.8527187,7,"Cartagena del Chairá","Caquetá"),
(1.6800635,-75.2921117,7,"El Doncello","Caquetá"),
(1.9110052,-75.1638453,7,"Puerto Rico","Caquetá"),
(5.8806597,-71.9016882,7,"Paz de Ariporo","Casanare"),
(4.6112946,-72.9469076,7,"Villanueva_Casanare","Casanare"),
(5.0101728,-72.7680475,7,"Tauramena","Casanare"),
(5.4078257,-71.6657436,7,"Trinidad","Casanare"),
(8.9591944,-73.6300878,7,"Pailitas","Cesar"),
(8.6904748,-73.6714595,7,"Pelaya","Cesar"),
(9.4957362,-73.9805817,7,"Astrea","Cesar"),
(9.2547864,-73.8213709,7,"Chimichagua","Cesar"),
(9.3627967,-73.6076467,7,"Chiriguaná","Cesar"),
(9.1011699,-75.4137808,7,"Chinú","Cordoba"),
(1.805187,-75.8971162817,7,"Acevedo","Huila"),
(10.6048369,-72.9890753,7,"Villanueva_Guajira","La Guajira"),
(11.2718854,-73.3120417,7,"Dibulla","La Guajira"),
(11.0683225,-72.7682152,7,"Hatonuevo","La Guajira"),
(10.4631193,-74.6256499,7,"Pivijay","Magdalena"),
(9.1445475,-74.2350703,7,"Guamal","Magdalena"),
(4.0914393,-72.991024,7,"Puerto López","Meta"),
(4.2666371,-73.5050382,7,"Cumaral","Meta"),
(4.3129983,-72.0923497,7,"Puerto Gaitán","Meta"),
(3.1279049,-73.7612887,7,"Vistahermosa","Meta"),
(2.4793217,-78.1145991,10,"El Charco","Nariño"),
(8.0851031,-72.8043246,7,"Sardinata","Norte de Santander"),
(7.3053636,-72.4886835,7,"Toledo","Norte de Santander"),
(8.5113708,-73.4494468,7,"El Carmen","Norte de Santander"),
(6.8785431,-73.4195401,7,"San Vicente de Chucurí","Santander"),
(7.3948132,-73.5088311,7,"Sabana de Torres","Santander"),
(6.7038792,-72.7386677,7,"Málaga","Santander"),
)

data = pandas.DataFrame(list(data), columns= ['Longitud', 'Latitud', 'radio', 'ciudad', 'dep'])
data = data.drop(['radio','dep'], axis=1)
data = data.sort_values(by='ciudad')
data = data.set_index('ciudad')

# %%
origen = "/src/static/ctc/TWITTER_COLOMBIA_FREQ.csv"
destino = "/src/static/ctc/CTC_HSIG.csv"

# %% [markdown]
# ## Definición de funciones

# %%
# Validar Valor de HSIC antes de Calcular PVALUE
def hsic_conditional_pvalue_cal(minhsic, x, y, samples):
    hsic_sin_p = HSIC.HSIC_no_pval(x,y)
    if hsic_sin_p > minhsic:
        hsic = HSIC.HSIC_pval(x,y,kernelX="Gaussian", kernelY="Gaussian", N_samp=samples)
        return hsic
    else:
        return False

def escribir_cabezote_archivo(destino, fieldnames):
    with open(destino, 'w') as csvfile:
        writer = fieldnames.to_csv(csvfile,sep="\t",decimal=",",header=fieldnames.columns)
        
def escribir_datos_archivo(destino, values):
    with open(destino, 'a') as csvfile:
        writer = values.to_csv(csvfile,sep="\t",decimal=",",header=False)

# %%
reader = pandas.read_csv(origen, chunksize=1, index_col=0, sep =",", quotechar='"')
count=0
valid_count = 0
for chunck  in reader:
    if (count>4):         
        start_time = time.time()
        cho=chunck.drop(['total','lower','titled','upper','other'], axis=1).transpose().sort_index()
        hsic=hsic_conditional_pvalue_cal(0.0015, data.as_matrix(),cho.as_matrix(), 500)
        if hsic:
            elapsed_time = time.time() - start_time
            valid_count+=1
            if valid_count == 1:
                basic_header = []
                basic_header.insert(0, { cho.columns.values[0]: hsic[0]})
                basic_header.insert(1, { cho.columns.values[0]: hsic[1]})
                cho=pandas.concat([pandas.DataFrame(basic_header, index=['HSIC','PVALUE']), cho])
                escribir_cabezote_archivo(destino, cho.transpose())
                print ('\r duracion:{}:{}'.format(elapsed_time,valid_count),end='\t\t\t\t\t\t\t\t\t\r')
                
            if valid_count > 1:
                basic_header = []
                basic_header.insert(0, { cho.columns.values[0]: hsic[0]})
                basic_header.insert(1, { cho.columns.values[0]: hsic[1]})
                cho=pandas.concat([pandas.DataFrame(basic_header, index=['HSIC','PVALUE']), cho])
                escribir_datos_archivo(destino, cho.transpose())
                print ('\r duracion:{} tokens_validos:{}'.format(elapsed_time,valid_count),end='\t\t\t\t\t\t\t\t\t\r')
                
    count+=1
    print ('\r{}'.format(count),end='\t\t\t\t\t\t\t\t\t\r')
# Out:
# 15261									81696271896362 tokens_validos:7484
# /opt/conda/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# 582540									015937805176 tokens_validos:11358
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-149-8c16e6663e63> in <module>()
#       6         start_time = time.time()
#       7         cho=chunck.drop(['total','lower','titled','upper','other'], axis=1).transpose().sort_index()
# ----> 8         hsic=hsic_conditional_pvalue_cal(0.0015, data.as_matrix(),cho.as_matrix(), 500)
#       9         if hsic:
#      10             elapsed_time = time.time() - start_time
#
# <ipython-input-137-3d997df412ab> in hsic_conditional_pvalue_cal(minhsic, x, y, samples)
#       1 # Validar Valor de HSIC antes de Calcular PVALUE
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-151-98a715344fbc> in <module>()
#       1 WORDS = {}
#       2 ORIGEN_HSIG = ("/src/static/ctc/CTC_HSIC_PVALUE_01.csv")
# ----> 3 reader = pandas.read_csv(ORIGEN_HSIG, index_col=0, sep =",", quotechar='"')
#       4
#       5 reader
#
# ...
