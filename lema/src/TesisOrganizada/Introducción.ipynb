# %% [markdown]
# # Dialectonos:
# ## Búsqueda de fronteras dialectales estadísticamente significativas.

# %%
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib nbagg

# %%
amp = widgets.FloatSlider(min=1, max=10, value=1, description="Amplitud" )
fas = widgets.FloatSlider(min=0, max=5, value=0, description="Fase" )
fre = widgets.FloatSlider(min=1, max=10, value=1, description="Frecuencia" )


def update_plot(amp,fas,fre):
    ax.clear()
    y = amp * np.sin(2 * np.pi * (fre * x +fas ))
    ax.plot(x,y)
    plt.show()
    
display(amp,fas, fre)

x = np.linspace(0,2,1000)
fig, ax = plt.subplots(1, figsize=(10,4))
plt.suptitle('Onda senoidal')

widgets.interactive(update_plot, amp=amp, fas=fas, fre=fre )
# Out:
# FloatSlider(value=1.0, description='Amplitud', max=10.0, min=1.0)
# FloatSlider(value=0.0, description='Fase', max=5.0)
# FloatSlider(value=1.0, description='Frecuencia', max=10.0, min=1.0)
# <img src="data:image/png;base64,..." width="1000">
# interactive(children=(FloatSlider(value=1.0, description='Amplitud', max=10.0, min=1.0), FloatSlider(value=0.0…
